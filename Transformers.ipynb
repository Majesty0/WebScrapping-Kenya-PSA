# %%
# ============================================================
# CELL 24: INSTALL TRANSFORMERS
# ============================================================

# !pip install transformers torch sentencepiece accelerate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (5.13.1)
# Requirement already satisfied: torch in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (2.13.0)
# Requirement already satisfied: sentencepiece in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (0.2.2)
# Requirement already satisfied: accelerate in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (1.14.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (1.23.0)
# Requirement already satisfied: numpy>=1.17 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (2026.7.10)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (0.26.8)
# Requirement already satisfied: safetensors>=0.8.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from transformers) (4.68.4)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub<2.0,>=1.5.0->transformers) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from torch) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from torch) (3.1.6)
# Requirement already satisfied: psutil in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
# ============================================================
# CELL 25: IMPORT NLP LIBRARIES
# ============================================================

from transformers import pipeline

print("Transformers imported successfully.")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ============================================================
#       2 # CELL 25: IMPORT NLP LIBRARIES
#       3 # ============================================================
# ----> 5 from transformers import pipeline
#       7 print("Transformers imported successfully.")
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\__init__.py:27
#      25 from .. import __version__
#      26 from .backbone_utils import BackboneConfigMixin, BackboneMixin
# ---> 27 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#      28 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      29 from .doc import (
#      30     add_code_sample_docstrings,
#      31     add_end_docstrings,
#    (...)
#      35     replace_return_docstrings,
#      36 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\chat_template_utils.py:39
#      36     from PIL.Image import Image
#      38 if is_torch_available():
# ---> 39     from torch import Tensor
#      42 BASIC_TYPES = (int, float, str, bool, Any, type(None), ...)
#      43 # Extracts the initial segment of the docstring, containing the function description
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:288
#     284                     raise err
#     286         kernel32.SetErrorMode(prev_error_mode)
# --> 288     _load_dll_libraries()
#     289     del _load_dll_libraries
#     292 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     293     # Libraries can either be in
#     294     # path/nvidia/lib_folder/lib or
#     295     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     296     # path/lib_folder/lib
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:271, in _load_dll_libraries()
#     267     err = ctypes.WinError(last_error)
#     268     err.strerror += (
#     269         f' Error loading "{dll}" or one of its dependencies.'
#     270     )
# --> 271     raise err
#     272 elif res is not None:
#     273     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
# ============================================================
# CELL 26: LOAD THE MODEL
# ============================================================

classifier = pipeline(
    task="zero-shot-classification",
    model="facebook/bart-large-mnli"
)

print("Model loaded successfully.")
# Out:
# WARNING:tensorflow:From c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# model.safetensors:  68%|######8   | 1.11G/1.63G [00:00<?, ?B/s]
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:140: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin\.cache\huggingface\hub\models--facebook--bart-large-mnli. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# WARNING:tensorflow:From c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBartForSequenceClassification: ['model.decoder.version', 'model.encoder.version']
# - This IS expected if you are initializing TFBartForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBartForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBartForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForSequenceClassification for predictions without further training.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use 0
# Model loaded successfully.

# %%
# ============================================================
# CELL 27: GOVERNANCE LABELS
# ============================================================

labels = [

    "Anti-Corruption",

    "Public Participation",

    "Elections and Voter Education",

    "Public Service Delivery",

    "Devolution and Local Governance"

]

print(labels)
# Out:
# ['Anti-Corruption', 'Public Participation', 'Elections and Voter Education', 'Public Service Delivery', 'Devolution and Local Governance']

# %%
# ============================================================
# CELL 28: TEST THE MODEL
# ============================================================

sample = """

The Independent Electoral and Boundaries Commission
reminds all registered voters to verify their voter
registration details before the registration deadline.

"""

result = classifier(
    sample,
    labels
)

print(result)
# Out:
# {'sequence': '\n\nThe Independent Electoral and Boundaries Commission\nreminds all registered voters to verify their voter\nregistration details before the registration deadline.\n\n', 'labels': ['Public Participation', 'Elections and Voter Education', 'Public Service Delivery', 'Anti-Corruption', 'Devolution and Local Governance'], 'scores': [0.40172913670539856, 0.23781718313694, 0.14333827793598175, 0.14099332690238953, 0.07612206786870956]}

# %%
# ============================================================
# CELL 29: CLASSIFY A GOVERNANCE PSA
# ============================================================

def classify_psa(text):

    if not isinstance(text, str):
        return "Unknown", 0.0

    try:

        prediction = classifier(
            text[:1000],   # Limit input length
            labels
        )

        return (

            prediction["labels"][0],

            prediction["scores"][0]

        )

    except Exception:

        return "Unknown", 0.0

# %%
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (4.68.4)
# Requirement already satisfied: colorama in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from tqdm) (0.4.6)

# %%
# ============================================================
# CELL 30: CLASSIFY ALL PSAs
# ============================================================
from tqdm import tqdm
predictions = []

confidences = []

for article in tqdm(psa_df["text"]):

    category, confidence = classify_psa(article)

    predictions.append(category)

    confidences.append(confidence)

psa_df["Category"] = predictions

psa_df["Confidence"] = confidences

psa_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       5 predictions = []
#       7 confidences = []
# ----> 9 for article in tqdm(psa_df["text"]):
#      11     category, confidence = classify_psa(article)
#      13     predictions.append(category)
#
# NameError: name 'psa_df' is not defined
